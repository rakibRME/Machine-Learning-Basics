# %% [markdown]
# # Step 1: Import Python Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Step 2: Read the Dataset

# %%
df= pd.read_csv(r"D:\University\3-2\3211\Lab_5_Assignment\kerala.csv")
df.head(5)
# Out:
#   SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 0      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 1      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 2      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 4      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
#
#      SEP    OCT    NOV    DEC   ANNUAL RAINFALL FLOODS
# 0  197.7  266.9  350.8   48.4            3248.6    YES
# 1  491.6  358.4  158.3  121.5            3326.6    YES
# 2  341.8  354.1  157.0   59.0            3271.2    YES
# 3  222.7  328.1   33.9    3.3            3129.7    YES
# 4  217.2  383.5   74.4    0.2            2741.6     NO

# %% [markdown]
# # Step 3: Explore the Dataset

# %%
df .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBDIVISION       118 non-null    object
#  1   YEAR              118 non-null    int64
#  2   JAN               118 non-null    float64
#  3   FEB               118 non-null    float64
#  4   MAR               118 non-null    float64
#  5   APR               118 non-null    float64
#  6   MAY               118 non-null    float64
#  7   JUN               118 non-null    float64
#  8   JUL               118 non-null    float64
#  9   AUG               118 non-null    float64
#  10  SEP               118 non-null    float64
#  11  OCT               118 non-null    float64
#  12  NOV               118 non-null    float64
#  13  DEC               118 non-null    float64
#  14   ANNUAL RAINFALL  118 non-null    float64
#  15  FLOODS            118 non-null    object
# ...

# %%
df.shape
# Out:
# (118, 16)

# %%
df.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   118.000000  118.000000  118.000000  118.000000  118.000000
# mean   1959.500000   12.218644   15.633898   36.670339  110.330508
# std      34.207699   15.473766   16.406290   30.063862   44.633452
# min    1901.000000    0.000000    0.000000    0.100000   13.100000
# 25%    1930.250000    2.175000    4.700000   18.100000   74.350000
# 50%    1959.500000    5.800000    8.350000   28.400000  110.400000
# 75%    1988.750000   18.175000   21.400000   49.825000  136.450000
# max    2018.000000   83.500000   79.000000  217.200000  238.000000
#
#               MAY          JUN          JUL          AUG         SEP  \
# count  118.000000   118.000000   118.000000   118.000000  118.000000
# mean   228.644915   651.617797   698.220339   430.369492  246.207627
# std    147.548778   186.181363   228.988966   181.980463  121.901131
# min     53.400000   196.800000   167.500000   178.600000   41.300000
# ...

# %%
print(df.columns)
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', ' ANNUAL RAINFALL', 'FLOODS'],
#       dtype='object')

# %%
df1 = df.drop(['SUBDIVISION','FLOODS'],axis=1)
df1.head()
# Out:
#    YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG    SEP    OCT  \
# 0  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5  197.7  266.9
# 1  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8  491.6  358.4
# 2  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2  341.8  354.1
# 3  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8  222.7  328.1
# 4  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6  217.2  383.5
#
#      NOV    DEC   ANNUAL RAINFALL
# 0  350.8   48.4            3248.6
# 1  158.3  121.5            3326.6
# 2  157.0   59.0            3271.2
# 3   33.9    3.3            3129.7
# 4   74.4    0.2            2741.6

# %%
df1.corr()
# Out:
#                       YEAR       JAN       FEB       MAR       APR       MAY  \
# YEAR              1.000000 -0.225531  0.003879 -0.012842  0.086865 -0.059661
# JAN              -0.225531  1.000000  0.019613  0.078626  0.034807  0.071420
# FEB               0.003879  0.019613  1.000000  0.245375  0.123706 -0.083500
# MAR              -0.012842  0.078626  0.245375  1.000000  0.074014 -0.102961
# APR               0.086865  0.034807  0.123706  0.074014  1.000000 -0.114566
# MAY              -0.059661  0.071420 -0.083500 -0.102961 -0.114566  1.000000
# JUN              -0.174938  0.189375  0.054114  0.019000  0.072990  0.001235
# JUL              -0.223403  0.034423  0.005789  0.018330  0.014977 -0.046518
# AUG               0.044173  0.008677  0.023259  0.042411 -0.047842 -0.124412
# SEP               0.107655 -0.113502  0.066317  0.143850  0.012928  0.116860
# OCT              -0.030223 -0.035044  0.053133 -0.023066  0.113172  0.197102
# ...

# %%
df['FLOODS' ]. replace( ['YES', 'NO' ], [1,0],
inplace=True)
df. head(5)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10880\3927616054.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['FLOODS' ]. replace( ['YES', 'NO' ], [1,0],
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10880\3927616054.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %% [markdown]
# # Step 3: Feature Selection

# %%
from sklearn. feature_selection import SelectKBest
from sklearn.feature_selection import chi2

X= df.iloc[ :, 1:14]
Y= df.iloc[ :,- 1]

best_features= SelectKBest(score_func=chi2, k=3)
fit= best_features.fit(X,Y)


df_scores= pd.DataFrame(fit.scores_)
df_columns= pd.DataFrame(X.columns)

features_scores= pd.concat([df_columns, df_scores],
axis=1)
features_scores. columns= ['Features', 'Score' ]
features_scores.sort_values(by = 'Score' )
# Out:
#    Features        Score
# 4       APR     2.498771
# 2       FEB     2.571626
# 0      YEAR     2.866463
# 12      DEC    11.609546
# 10      OCT    12.650485
# 3       MAR    21.696518
# 1       JAN    48.413088
# 11      NOV   284.674615
# 5       MAY   656.812145
# 8       AUG   739.975818
# 9       SEP  1000.379273
# 6       JUN  1218.856252
# 7       JUL  1722.612175

# %% [markdown]
# # Step 4: Build the Model

# %%
X= df[['SEP', 'JUN', 'JUL']] 
Y= df[['FLOODS' ]]

X_train, X_test, y_train,y_test=train_test_split(X,Y,test_size=0.4, random_state=100)

logreg= LogisticRegression()
logreg. fit(X_train,y_train)

y_pred=logreg.predict(X_test)
print (X_test) 
print (y_pred)
# Out:
#        SEP     JUN     JUL
# 84   117.6   828.7   388.9
# 85   235.4   597.9   324.8
# 37   223.2   681.6   648.6
# 45   199.4   919.0   671.7
# 97   517.6   732.5   641.4
# 26   335.6   720.2   888.2
# 101   99.0   503.1   318.7
# 112  318.6  1042.7   830.2
# 21   222.4   663.1  1025.1
# 33    48.4   852.9   415.0
# 11   136.8   948.2   833.6
# 46   394.5   556.1   669.3
# 96   292.2   544.2   970.5
# 25   322.7   563.9   885.2
# 32   469.7   859.3   773.4
# 99   195.8   633.8   343.2
# 108  326.5   438.2   924.9
# 51    57.4   576.7   430.0
# 29   411.5   633.1   401.7
# 64   150.1   597.7   465.1
# 28   268.9   946.6   844.0
# 90    48.5  1096.1   905.5
# 89   103.3   528.6   635.4
# 54   438.5   782.4   392.8
# 35   286.7   620.8   672.1
# 43   155.0   498.9   614.1
# 73   383.6   266.9  1004.2
# 80   376.6   912.4   489.8
# 36   139.8   485.6   970.5
# 75   116.2   196.8   641.5
# 22   254.3   722.5  1008.7
# 82   421.1   322.8   583.2
# 113  298.8   454.4   677.8
# ...

# %% [markdown]
# # Step 5: Evaluate the Model's Performance

# %%
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import classification_report

print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
print('Recall: ', metrics.recall_score(y_test, y_pred, zero_division=1))
print("Precision:", metrics.precision_score(y_test, y_pred, zero_division=1))
print("CL Report:\n", metrics.classification_report(y_test, y_pred, zero_division=1))

y_pred_proba = logreg.predict_proba(X_test)[:, 1]

false_positive_rate, true_positive_rate, thresholds = metrics.roc_curve(y_test, y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)

plt.plot(false_positive_rate, true_positive_rate, label="AUC=" + str(auc))
plt.title('ROC Curve')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# Accuracy:  0.8541666666666666
# Recall:  0.8846153846153846
# Precision: 0.8518518518518519
# CL Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84        22
#            1       0.85      0.88      0.87        26
#
#     accuracy                           0.85        48
#    macro avg       0.85      0.85      0.85        48
# weighted avg       0.85      0.85      0.85        48

# %% [markdown]
# # Predict rainfall in September, June, July using LinearRegression from 1901 to 2018

# %%
from sklearn.linear_model import LogisticRegression, LinearRegression
if 'Year' not in df.columns:
    df['Year'] = df.index + 2010  

X = df[['Year']]  
y_sep = df['SEP']  
y_jun = df['JUN']  
y_jul = df['JUL']  

for col in ['SEP', 'JUN', 'JUL']:
    if col not in df.columns:
        raise KeyError(f"Column '{col}' does not exist in the DataFrame.")

X_train, X_test, y_sep_train, y_sep_test = train_test_split(X, y_sep, test_size=0.2, random_state=0)
X_train, X_test, y_jun_train, y_jun_test = train_test_split(X, y_jun, test_size=0.2, random_state=0)
X_train, X_test, y_jul_train, y_jul_test = train_test_split(X, y_jul, test_size=0.2, random_state=0)

model_sep = LinearRegression()
model_jun = LinearRegression()
model_jul = LinearRegression()

model_sep.fit(X_train, y_sep_train)
model_jun.fit(X_train, y_jun_train)
model_jul.fit(X_train, y_jul_train)

year_to_predict = np.array([[2025]])

predicted_sep = model_sep.predict(year_to_predict)
predicted_jun = model_jun.predict(year_to_predict)
predicted_jul = model_jul.predict(year_to_predict)

print(f"Predicted rainfall in September 2025: {predicted_sep[0]:.2f} mm")
print(f"Predicted rainfall in June 2025: {predicted_jun[0]:.2f} mm")
print(f"Predicted rainfall in July 2025: {predicted_jul[0]:.2f} mm")
# Out:
# Predicted rainfall in September 2025: 240.56 mm
# Predicted rainfall in June 2025: 698.11 mm
# Predicted rainfall in July 2025: 778.99 mm
# e:\mlenv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# e:\mlenv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# e:\mlenv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Flood prediction for 2025 using predicted rainfall

# %%
expected_sep = predicted_sep[0]  
expected_jun = predicted_jun[0]  
expected_jul = predicted_jul[0]  

predicted_2025 = np.array([[expected_sep, expected_jun, expected_jul]])

flood_prediction_2025 = logreg.predict(predicted_2025)

print(f"Flood prediction for 2025: {'Yes' if flood_prediction_2025[0] == 1 else 'No'}")
# Out:
# Flood prediction for 2025: Yes
# e:\mlenv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
