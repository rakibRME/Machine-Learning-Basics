# %%
pip install rembg
# Out:
# ...
#   Obtaining dependency information for rembg from https://files.pythonhosted.org/packages/80/f3/426699cd8324c7735d626e3dd026e7ed1633cb1cd9435b41ea7d84f509d6/rembg-2.0.59-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for onnxruntime from https://files.pythonhosted.org/packages/1e/f5/9d995a685f97508b3254f17015b4a78641b0625e79480a7aed7a7a105d7c/onnxruntime-1.19.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for opencv-python-headless from https://files.pythonhosted.org/packages/26/d0/22f68eb23eea053a31655960f133c0be9726c6a881547e6e9e7e2a946c4f/opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pooch from https://files.pythonhosted.org/packages/a8/87/77cc11c7a9ea9fd05503def69e3d18605852cd0d4b0d3b8f15bbeb3ef1d1/pooch-1.8.2-py3-none-any.whl.metadata
# ...

# %%
from rembg import remove
from PIL import Image
input_path = r"C:\Users\ASUS\Pictures\hgd.jpg"
output_path = "D:\ML-Data-Sets.png"
input = Image.open(input_path)
output = remove(input)
output.save(output_path)
