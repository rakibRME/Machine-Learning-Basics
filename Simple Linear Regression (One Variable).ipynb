# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error

# %%
dataset = pd.read_csv("D:\ML-Data-Sets\Salary_dataset.csv")
dataset.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16808\2690607479.py:1: SyntaxWarning: invalid escape sequence '\M'
#   dataset = pd.read_csv("D:\ML-Data-Sets\Salary_dataset.csv")
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
plt.scatter(x,y,color="red")
plt.title("Experience X Salary")
plt.xlabel=("Experience")
plt.ylabel=("Salary")

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %%
regressor = LinearRegression()
model=regressor.fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)
# Out:
# MSE: 51338023.49224833

# %%
rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 7165.0557215033805

# %%
rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred))
print("RMSLE:", rmsle)
# Out:
# RMSLE: 0.08762953076725276

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7616681465472098

# %%
plt.scatter(x_train,y_train,color="red")
plt.plot(x_train,model.predict(x_train),color="blue")
plt.title("Experience X Salary")
plt.xlabel=("Experience")
plt.ylabel=("Salary")

# %%
plt.scatter(x_test,y_test,color="red")
plt.plot(x_train,model.predict(x_train),color="blue")
plt.title("Experience X Salary")
plt.xlabel=("Experience")
plt.ylabel=("Salary")

# %%
plt.scatter(x,y,color="red")
plt.plot(x_train,model.predict(x_train),color="blue")
plt.title("Experience X Salary")
plt.xlabel=("Experience")
plt.ylabel=("Salary")
